# %% [markdown]
# # Exploratory  Data Analysis with Python
# ### Creative Music vs. All of Music
# [Takato Matsumoto](takato.matsumoto0114@gmail.com)

# %%
#ライブラリの読み込み
import pandas as pd
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import matplotlib.pyplot as plt
import os.path
plt.style.use('ggplot')
plt.rcParams['font.family'] = 'IPAexGothic'
plt.rcParams['font.size'] = 16
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15,10)

# %%
authors = ['takato', 'fujisan', 'haradasan', 'muratasan']

for i, author in enumerate(authors):
    file_name = '../datasets/' + author + '.csv'
    exec(f"df_{author} = pd.read_csv(file_name).drop([ 'analysis_url', 'track_href', 'uri',  'type',  'id','time_signature','mode','duration_ms','liveness'], axis=1)")

# %%
df = pd.read_csv('../datasets/madeon_radio.csv')
df = df.drop([ 'analysis_url', 'track_href', 'uri',  'type',  'id','time_signature','mode','duration_ms','liveness'], axis=1)
df_vivaldi = pd.read_csv('../datasets/vivaldi_radio.csv')
df_vivaldi = df_vivaldi.drop([ 'analysis_url', 'track_href', 'uri',  'type',  'id','time_signature','mode','duration_ms','liveness'], axis=1)
#df_haradasan.drop(['genre'], axis=1)

# %%
df_all = pd.concat([df_takato, df_haradasan, df_fujisan, df_muratasan])

# %%
df_all.head()
# Out:
#    danceability  energy  key  loudness  speechiness  acousticness  \
# 0         0.673   0.886    1    -4.440       0.0431       0.18500
# 1         0.637   0.843    5    -5.413       0.0432       0.01510
# 2         0.749   0.925   10    -5.034       0.2270       0.24100
# 3         0.766   0.376   10    -8.622       0.0267       0.25200
# 4         0.751   0.783    4    -3.724       0.0859       0.00379
#
#    instrumentalness  valence    tempo
# 0           0.00000    0.795   97.012
# 1           0.00000    0.434  109.012
# 2           0.00000    0.641   86.989
# 3           0.00861    0.257  109.943
# 4           0.00000    0.816  119.975

# %%
#データのカラムのチェック
df = pd.concat([df_all, df_creative])
df = df[~df.duplicated(keep=False)]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88598 entries, 0 to 14
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      88598 non-null  float64
#  1   energy            88598 non-null  float64
#  2   key               88598 non-null  int64
#  3   loudness          88598 non-null  float64
#  4   speechiness       88598 non-null  float64
#  5   acousticness      88598 non-null  float64
#  6   instrumentalness  88598 non-null  float64
#  7   valence           88598 non-null  float64
#  8   tempo             88598 non-null  float64
#  9   genre             15 non-null     object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 7.4+ MB

# %%
sns.pairplot(df_creative, hue='genre')
plt.savefig('pariplot.png')

# %% [markdown]
# # 1. Histogram

# %%
f, axes = plt.subplots(7, 2, figsize=(15, 30), sharex=False)
sns.despine(left=True)

for i, col in enumerate(df_takato.columns):
    sns.distplot(df[col] ,kde=True, rug=False, hist=False, kde_kws={"shade": True}, color='c', ax=axes[int(i /2), i%2], label='radio')
    #sns.distplot(df_haradasan[col] ,kde=True, rug=False, hist=False, kde_kws={"shade": True}, color='m',ax=axes[int(i/2), i%2], label='haradasan')
    #sns.distplot(df_[col] ,kde=True, rug=False, hist=False, kde_kws={"shade": True}, color='y',ax=axes[int(i/2), i%2], label='muratasan')
    #sns.distplot(df_muratasan[col] ,kde=True, rug=False, hist=False, kde_kws={"shade": True}, color='b',ax=axes[int(i/2), i%2], label='madeon_album')
    sns.distplot(df_vivaldi[col] ,kde=True, rug=False, hist=False, kde_kws={"shade": True}, color='b',ax=axes[int(i/2), i%2], label='vivaldi')
plt.savefig('histogram.png')
#0.7 > danceability > 0.5 & 0.8 > energy > 0.6 & speechiness < 0.05 & acousticness < 0.2 & instrumentalness > 0.8 & valence < 0.3

# %%
f, axes = plt.subplots(7, 2, figsize=(15, 30), sharex=False)
sns.despine(left=True)

for i, col in enumerate(df_creative.columns):
    sns.distplot(df_creative[col] ,kde=True, rug=False, hist=False, kde_kws={"shade": True}, color='c', ax=axes[int(i /2), i%2], label='creative music')
    sns.distplot(df_all[col] ,kde=True, rug=False, hist=False, kde_kws={"shade": True}, color='m',ax=axes[int(i/2), i%2], label='all')

plt.savefig('scatter.png')
